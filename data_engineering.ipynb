# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import t
from scipy import stats
from apyori import apriori

# %%
pd.set_option('display.max_rows', 200)

# %%
df = pd.read_csv('mma_mart.csv')

# %% [markdown]
# ### Seperate refrigerated beerages

# %%
df.loc[df['aisle'] == 'refrigerated', 'department'] = 'beverages_refrigerated'
df.loc[df['department'] == 'beverages', 'department'] = 'beverages_non_refrigerated'

# %% [markdown]
# ### Remove 'missing' department and 'missing' aisle

# %%
df = df[df['department'] != 'missing']

# %% [markdown]
# ### Mark products as refrigerated or frozen

# %%
df['frozen'] = df['department'] == 'frozen'
dept_refrigerated = ['dairy eggs', 'deli', 'meat seafood', 'beverages_refrigerated']
df['refrigerated'] = df['department'].isin(dept_refrigerated)

# %% [markdown]
# ### Largest Remainder Method

# %%
def largest_remainder_method(decimal_series):
    total_percentage = 100
    rounded_percentages = [round(decimal * total_percentage) for decimal in decimal_series]

    # Calculate the total after rounding
    rounded_total = sum(rounded_percentages)

    # Calculate the remainder for each percentage
    remainders = [(i, rounded_percentage % 1) for i, rounded_percentage in enumerate(rounded_percentages)]

    # Sort the remainders in descending order
    remainders.sort(key=lambda x: x[1], reverse=True)

    # Distribute the remaining percentage to the largest remainders
    remaining_percentage = total_percentage - rounded_total
    for i in range(remaining_percentage):
        index = remainders[i % len(remainders)][0]
        rounded_percentages[index] += 1

    return rounded_percentages

# %% [markdown]
# ### Create Refrigerated products dataframe

# %%
df_refrige = df[df['refrigerated'] == True]

# %%
refridge_dept_counts = df_refrige.groupby('department').agg(
    products_sold=pd.NamedAgg(column='product_name', aggfunc='nunique'),
    total_items_sold=pd.NamedAgg(column='product_name', aggfunc='size')
).reset_index()

refridge_dept_counts['store_util'] = refridge_dept_counts['products_sold'] / refridge_dept_counts['products_sold'].sum()
refridge_dept_counts['dept_dominance'] = refridge_dept_counts['total_items_sold'] / refridge_dept_counts['total_items_sold'].sum()
refridge_dept_counts['aisle_allocation'] = largest_remainder_method(((refridge_dept_counts['store_util']+refridge_dept_counts['dept_dominance'] ) / 2))
#refridge_dept_counts.loc[refridge_dept_counts['department'] == 'beverages', 'department'] = 'beverages_refrigerated'

# %%
refridge_dept_counts
# Out:
#                department  products_sold  total_items_sold  store_util  \
# 0  beverages_refrigerated            544             17663    0.104797
# 1              dairy eggs           2886            164468    0.555962
# 2                    deli           1069             32008    0.205933
# 3            meat seafood            692             21588    0.133308
#
#    dept_dominance  aisle_allocation
# 0        0.074930                 9
# 1        0.697705                63
# 2        0.135784                17
# 3        0.091581                11

# %%
# Create a dictionary from the two columns
dept_allocation = dict(zip(refridge_dept_counts['department'], refridge_dept_counts['aisle_allocation']))

# %% [markdown]
# ### Create General products dataframe

# %%
df_general = df[(df['refrigerated'] == False) & (df['frozen'] == False)]

# %%
general_dept_counts = df_general.groupby('department').agg(
    products_sold=pd.NamedAgg(column='product_name', aggfunc='nunique'),
    total_items_sold=pd.NamedAgg(column='product_name', aggfunc='size')
).reset_index()

general_dept_counts['store_util'] = general_dept_counts['products_sold'] / general_dept_counts['products_sold'].sum()
general_dept_counts['dept_dominance'] = general_dept_counts['total_items_sold'] / general_dept_counts['total_items_sold'].sum()
general_dept_counts['aisle_allocation'] = largest_remainder_method((general_dept_counts['store_util']+general_dept_counts['dept_dominance'] ) / 2)
general_dept_counts['aisle_allocation'] = general_dept_counts['aisle_allocation'] * 8
#general_dept_counts.loc[general_dept_counts['department'] == 'beverages', 'department'] = 'beverages_non_refrigerated'

# %%
general_dept_counts
# Out:
#                     department  products_sold  total_items_sold  store_util  \
# 0                      alcohol            606              4580    0.023100
# 1                       babies            799             12872    0.030457
# 2                       bakery           1204             35806    0.045895
# 3   beverages_non_refrigerated           2709             64260    0.103263
# 4                    breakfast            905             21585    0.034497
# 5                         bulk             33              1087    0.001258
# 6                 canned goods           1557             32486    0.059350
# 7              dry goods pasta           1366             26096    0.052070
# 8                    household           2028             22445    0.077304
# 9                international            772              8248    0.029427
# 10                       other            303              1097    0.011550
# 11                      pantry           3691             56681    0.140695
# 12               personal care           3524             13773    0.134329
# 13                        pets            657              3157    0.025044
# 14                     produce           1437            288775    0.054776
# 15                      snacks           4643             88093    0.176984
#
#     dept_dominance  aisle_allocation
# 0         0.006725                16
# 1         0.018900                16
# 2         0.052575                40
# 3         0.094356                80
# 4         0.031694                24
# 5         0.001596                 0
# 6         0.047701                40
# 7         0.038318                40
# 8         0.032957                48
# 9         0.012111                16
# 10        0.001611                 8
# 11        0.083227                88
# 12        0.020223                64
# 13        0.004636                 8
# 14        0.424020               192
# 15        0.129351               120

# %%
# Create a new dictionary from the DataFrame
temp_dict = dict(zip(general_dept_counts['department'], general_dept_counts['aisle_allocation']))
# Add the new dictionary to the existing dictionary
dept_allocation.update(temp_dict)
dept_allocation['frozen'] = 100

# %%
dept_allocation
# Out:
# {'beverages_refrigerated': 9,
#  'dairy eggs': 63,
#  'deli': 17,
#  'meat seafood': 11,
#  'alcohol': 16,
#  'babies': 16,
#  'bakery': 40,
#  'beverages_non_refrigerated': 80,
#  'breakfast': 24,
#  'bulk': 0,
#  'canned goods': 40,
#  'dry goods pasta': 40,
#  'household': 48,
#  'international': 16,
#  'other': 8,
#  'pantry': 88,
#  'personal care': 64,
#  'pets': 8,
#  'produce': 192,
#  'snacks': 120,
#  'frozen': 100}

# %% [markdown]
# ### Check correlation between store_util and dept_dominance

# %%
# Calculate the correlation coefficient between the two variables
corr_coef = department_counts['store_util'].corr(department_counts['dept_dominance'])

print(f'Correlation coefficient between store_util and dept_dominance: {corr_coef}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Calculate the correlation coefficient between the two variables
# ----> 2 corr_coef = department_counts['store_util'].corr(department_counts['dept_dominance'])
#       4 print(f'Correlation coefficient between store_util and dept_dominance: {corr_coef}')
#
# NameError: name 'department_counts' is not defined

# %% [markdown]
# Weak correlation between the number of products within each department and the total number of sales between each department. This means having more products in your department does not lead to more department sales.

# %% [markdown]
# ### Confidence Interval of total_quantity_sold for each department

# %%
department_stats = {}

for department, data in top_1000.groupby('department'):
    mean_quantity = data['total_quantity_sold'].mean()
    std_quantity = data['total_quantity_sold'].std()
    sem_quantity = stats.sem(data['total_quantity_sold'])
    confidence_interval = [round(val, 2) for val in stats.t.interval(0.95, len(data)-1, loc=mean_quantity, scale=sem_quantity)]
    
    department_stats[department] = {
        'mean_quantity': round(mean_quantity, 2),
        'std_quantity': round(std_quantity, 2),
        'confidence_interval': confidence_interval
    }

# Display the results
for department, info in department_stats.items():
    print(f"Department: {department}")
    print(f"Mean Quantity Sold: {info['mean_quantity']}")
    print(f"Standard Deviation: {info['std_quantity']}")
    print(f"Confidence Interval: {info['confidence_interval']}")
    print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 department_stats = {}
# ----> 3 for department, data in top_1000.groupby('department'):
#       4     mean_quantity = data['total_quantity_sold'].mean()
#       5     std_quantity = data['total_quantity_sold'].std()
#
# NameError: name 'top_1000' is not defined

# %% [markdown]
# ### Top 1000 items sold

# %%
# Group by 'product_name' and sum rows for sales count
df_quantity_sold = df.groupby('product_name').size().reset_index(name='total_quantity_sold')

# Merge with df to carryover product details
df_quantity_sold = pd.merge(df_quantity_sold, df.drop_duplicates('product_name'), on='product_name')
df_quantity_sold = df_quantity_sold.sort_values(by='total_quantity_sold', ascending=False)
# Find top 1000 products
top_1000 = df_quantity_sold.head(1000)

# %%
top_1000[top_1000['department'] == 'beverages_refrigerated']
# Out:
#                                             product_name  total_quantity_sold  \
# 301                               100% Raw Coconut Water                 1142
# 23231                              Original Orange Juice                  752
# 21845                     Organic Raw Kombucha Gingerade                  657
# 15737                                           Lemonade                  608
# 23220         Original No Pulp 100% Florida Orange Juice                  577
# 31816                             Trilogy Kombucha Drink                  507
# 19472                                       Orange Juice                  506
# 25557                             Pulp Free Orange Juice                  310
# 18790      No Pulp Calcium & Vitamin D Pure Orange Juice                  290
# 30731               Synergy Organic Kombucha Gingerberry                  288
# 14808  Juice Beverage, Cold Pressed, Kale Apple Ginge...                  264
# 1784                                         Apple Juice                  258
# 9520                    Enlightened Organic Raw Kombucha                  223
# 10419      Florida Orange Juice With Calcium & Vitamin D                  216
# 21848                   Organic Raw Multigreen Kobmbucha                  210
# 19588         Organic & Raw Strawberry Serenity Kombucha                  209
# 30729             Synergy Organic & Raw Cosmic Cranberry                  200
# 10940                      Freshly Squeezed Orange Juice                  180
# 26039                                 Raspberry Lemonade                  174
#
#        order_id  product_id  aisle_id         aisle  department_id  \
# 301         190        3957        31  refrigerated              7
# 23231         4       25146        31  refrigerated              7
# 21845        98       30776        31  refrigerated              7
# 15737        13       41290        31  refrigerated              7
# 23220       321       31683        31  refrigerated              7
# 31816       301       45603        31  refrigerated              7
# 19472         7       34050        31  refrigerated              7
# 25557        72       39108        31  refrigerated              7
# 18790       459        6631        31  refrigerated              7
# 30731        30       48559        31  refrigerated              7
# 14808        83       13292        31  refrigerated              7
# 1784         99       38200        31  refrigerated              7
# 9520        189       19894        31  refrigerated              7
# 10419       359        8087        31  refrigerated              7
# 21848      1171        9421        31  refrigerated              7
# 19588       259        6287        31  refrigerated              7
# 30729       388        8736        31  refrigerated              7
# 10940       777       36127        31  refrigerated              7
# 26039       480       43967        31  refrigerated              7
#
#                    department  frozen  refrigerated
# 301    beverages_refrigerated   False          True
# 23231  beverages_refrigerated   False          True
# 21845  beverages_refrigerated   False          True
# 15737  beverages_refrigerated   False          True
# 23220  beverages_refrigerated   False          True
# 31816  beverages_refrigerated   False          True
# 19472  beverages_refrigerated   False          True
# 25557  beverages_refrigerated   False          True
# 18790  beverages_refrigerated   False          True
# 30731  beverages_refrigerated   False          True
# 14808  beverages_refrigerated   False          True
# 1784   beverages_refrigerated   False          True
# 9520   beverages_refrigerated   False          True
# 10419  beverages_refrigerated   False          True
# 21848  beverages_refrigerated   False          True
# 19588  beverages_refrigerated   False          True
# 30729  beverages_refrigerated   False          True
# 10940  beverages_refrigerated   False          True
# 26039  beverages_refrigerated   False          True

# %% [markdown]
# ### Find department breakdown of top_1000 products

# %%
top_1000_department_counts = top_1000.groupby('department').agg(
    products_sold=pd.NamedAgg(column='product_name', aggfunc='nunique'),
).reset_index()

# %%
top_1000_department_counts['dept_top_1000_dominance'] = top_1000_department_counts['products_sold'] / top_1000_department_counts['products_sold'].sum()

# %%
top_1000_department_counts
# Out:
#                     department  products_sold  dept_top_1000_dominance
# 0                      alcohol              4                    0.004
# 1                       babies              8                    0.008
# 2                       bakery             42                    0.042
# 3   beverages_non_refrigerated             69                    0.069
# 4       beverages_refrigerated             19                    0.019
# 5                    breakfast             16                    0.016
# 6                         bulk              2                    0.002
# 7                 canned goods             38                    0.038
# 8                   dairy eggs            229                    0.229
# 9                         deli             35                    0.035
# 10             dry goods pasta             31                    0.031
# 11                      frozen             69                    0.069
# 12                   household             10                    0.010
# 13               international              2                    0.002
# 14                meat seafood             24                    0.024
# 15                      pantry             47                    0.047
# 16               personal care              1                    0.001
# 17                     produce            267                    0.267
# 18                      snacks             87                    0.087

# %% [markdown]
# ### Find refridgerated breakdown of top_1000 products

# %%
top_1000_refrigerated = top_1000[top_1000['refrigerated'] == True]

print(f'Number of refrigerated products in the top_1000: {top_1000_refrigerated.shape[0]}')
# Out:
# Number of refrigerated products in the top_1000: 307

# %%
# Dateframe of the top 100 refrigerated products
top_100_refrigerated = top_1000_refrigerated.head(100)

# %% [markdown]
# ### Picking Top 1000

# %%
selected_rows = []

# Iterate through the dictionary and DataFrame to pick items
for department, num_items in dept_allocation.items():
    department_rows = df_quantity_sold[df_quantity_sold['department'] == department].head(num_items)
    selected_rows.append(department_rows)

# Concatenate the selected rows into a new DataFrame
picked_df = pd.concat(selected_rows)

# %%
picked_df.head(10)
# Out:
#                                         product_name  total_quantity_sold  \
# 301                           100% Raw Coconut Water                 1142
# 23231                          Original Orange Juice                  752
# 21845                 Organic Raw Kombucha Gingerade                  657
# 15737                                       Lemonade                  608
# 23220     Original No Pulp 100% Florida Orange Juice                  577
# 31816                         Trilogy Kombucha Drink                  507
# 19472                                   Orange Juice                  506
# 25557                         Pulp Free Orange Juice                  310
# 18790  No Pulp Calcium & Vitamin D Pure Orange Juice                  290
# 22719                             Organic Whole Milk                 4089
#
#        order_id  product_id  aisle_id         aisle  department_id  \
# 301         190        3957        31  refrigerated              7
# 23231         4       25146        31  refrigerated              7
# 21845        98       30776        31  refrigerated              7
# 15737        13       41290        31  refrigerated              7
# 23220       321       31683        31  refrigerated              7
# 31816       301       45603        31  refrigerated              7
# 19472         7       34050        31  refrigerated              7
# 25557        72       39108        31  refrigerated              7
# 18790       459        6631        31  refrigerated              7
# 22719        14       27845        84          milk             16
#
#                    department  frozen  refrigerated
# 301    beverages_refrigerated   False          True
# 23231  beverages_refrigerated   False          True
# 21845  beverages_refrigerated   False          True
# 15737  beverages_refrigerated   False          True
# 23220  beverages_refrigerated   False          True
# 31816  beverages_refrigerated   False          True
# 19472  beverages_refrigerated   False          True
# 25557  beverages_refrigerated   False          True
# 18790  beverages_refrigerated   False          True
# 22719              dairy eggs   False          True

# %%
#picked_df.to_csv('items_1000.csv', index=False)

# %%
# Filter rows where 'column1' contains the word 'garlic'
filtered_df = picked_df[picked_df['product_name'].str.contains('apple', case=False)]

filtered_df
# Out:
#                                             product_name  total_quantity_sold  \
# 3806                  Broccoli & Apple Stage 2 Baby Food                  196
# 29686  Stage 1 Apples Sweet Potatoes Pumpkin & Bluebe...                  184
# 1837                  Apple and Carrot Stage 2 Baby Food                  128
# 19708                                Organic Apple Juice                  335
# 19710                          Organic Apple Juice Boxes                  184
# 259                                100% Pure Apple Juice                  175
# 83                                      100% Apple Juice                  162
# 24536                           Pink Lady Apple Kombucha                  159
# 1764                      Apple Cinnamon Instant Oatmeal                  173
# 19720                                 Organic AppleApple                  491
# 1815                                         Apple Sauce                  190
# 12223  Gogo Squeez Organic Apple Strawberry Applesauc...                  171
# 21856         Organic Raw Unfiltered Apple Cider Vinegar                  269
# 1751                                 Apple Cider Vinegar                  258
# 20697                                 Organic Fuji Apple                 2692
# 1782                            Apple Honeycrisp Organic                 2579
# 14000                                   Honeycrisp Apple                 2467
# 20705                                Organic Gala Apples                 2307
# 21165               Organic Large Extra Fancy Fuji Apple                 2272
# 20818                         Organic Granny Smith Apple                 1749
# 12532                                Granny Smith Apples                 1083
# 11346                                        Gala Apples                  691
# 21871                        Organic Red Delicious Apple                  437
# 20371                         Organic Cripps Pink Apples                  386
# 14003                                  Honeycrisp Apples                  377
# 1841                                              Apples                  370
# 20799                     Organic Golden Delicious Apple                  305
# 19944                             Organic Braeburn Apple                  291
# 1761                          Apple Cinnamon GoGo Squeez                  265
# 1807                      Apple Pie Fruit & Nut Food Bar                  220
# 19718                               Organic Apple Slices                  200
# 24475                                   Pineapple Chunks                  701
#
#        order_id  product_id  aisle_id                     aisle  \
# 3806        902        3020        92         baby food formula
# 29686      1376        5491        92         baby food formula
# 1837        163       47888        92         baby food formula
# 19708       529       18811        98             juice nectars
# 19710      1521       13113        98             juice nectars
# 259         254       45840        98             juice nectars
# 83          480       35199        98             juice nectars
# 24536       657        4462        94                       tea
# 1764        123       37464       130  hot cereal pancake mixes
# 19720       105       26790        99   canned fruit applesauce
# 1815        672       45013        99   canned fruit applesauce
# 12223       192        9598        99   canned fruit applesauce
# 21856        38        4461        19             oils vinegars
# 1751         52       18963        19             oils vinegars
# 20697        39       28204        24              fresh fruits
# 1782         77        8277        24              fresh fruits
# 14000        14       45066        24              fresh fruits
# 20705        53       37646        24              fresh fruits
# 21165        57       19057        24              fresh fruits
# 20818       163       39877        24              fresh fruits
# 12532        68        9387        24              fresh fruits
# 11346        52       39408        24              fresh fruits
# 21871        28       31915        24              fresh fruits
# 20371       177       40723        24              fresh fruits
# 14003       212       17122        24              fresh fruits
# 1841        146       13575        24              fresh fruits
# 20799       578       33055        24              fresh fruits
# 19944        55        6740        24              fresh fruits
# 1761         88       27690        50    fruit vegetable snacks
# 1807        153       33716         3       energy granola bars
# 19718      2720       42803        50    fruit vegetable snacks
# 24475         7       46802       116            frozen produce
#
#        department_id                  department  frozen  refrigerated
# 3806              18                      babies   False         False
# 29686             18                      babies   False         False
# 1837              18                      babies   False         False
# 19708              7  beverages_non_refrigerated   False         False
# 19710              7  beverages_non_refrigerated   False         False
# 259                7  beverages_non_refrigerated   False         False
# 83                 7  beverages_non_refrigerated   False         False
# 24536              7  beverages_non_refrigerated   False         False
# 1764              14                   breakfast   False         False
# 19720             15                canned goods   False         False
# 1815              15                canned goods   False         False
# 12223             15                canned goods   False         False
# 21856             13                      pantry   False         False
# 1751              13                      pantry   False         False
# 20697              4                     produce   False         False
# 1782               4                     produce   False         False
# 14000              4                     produce   False         False
# 20705              4                     produce   False         False
# 21165              4                     produce   False         False
# 20818              4                     produce   False         False
# 12532              4                     produce   False         False
# 11346              4                     produce   False         False
# 21871              4                     produce   False         False
# 20371              4                     produce   False         False
# 14003              4                     produce   False         False
# 1841               4                     produce   False         False
# 20799              4                     produce   False         False
# 19944              4                     produce   False         False
# 1761              19                      snacks   False         False
# 1807              19                      snacks   False         False
# 19718             19                      snacks   False         False
# 24475              1                      frozen    True         False
